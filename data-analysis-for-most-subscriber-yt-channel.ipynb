# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/most-subscribed-youtube-channel/Most Subscribed YouTube Channels_exported.csv

# %%
df = pd.read_csv("/kaggle/input/most-subscribed-youtube-channel/Most Subscribed YouTube Channels_exported.csv")
df.head()
# Out:
#                                   Name Brand channel  Subscribers (millions)  \
# 0                             T-Series           Yes                   249.0
# 1                              MrBeast            No                   184.0
# 2                            Cocomelon           Yes                   165.0
# 3  Sony Entertainment Television India           Yes                   162.0
# 4                      Kids Diana Show           Yes                   113.0
#
#       Primary language       Category                 Country
# 0          Hindi[7][8]          Music                   India
# 1              English  Entertainment           United States
# 2              English      Education           United States
# 3             Hindi[9]  Entertainment                   India
# 4  English[10][11][12]  Entertainment  Ukraine- United States

# %%
df.tail()
# Out:
#            Name Brand channel  Subscribers (millions) Primary language  \
# 45           A4            No                    47.2          Russian
# 46      Badabun           Yes                    47.0          Spanish
# 47    Bad Bunny            No                    46.4          Spanish
# 48  Har Pal Geo           Yes                    46.3             Urdu
# 49   Fernanfloo            No                    46.3          Spanish
#
#          Category                       Country
# 45  Entertainment                       Belarus
# 46  Entertainment                        Mexico
# 47          Music  United States ( Puerto Rico)
# 48  Entertainment                      Pakistan
# 49          Games                   El Salvador

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    50 non-null     object
#  1   Brand channel           50 non-null     object
#  2   Subscribers (millions)  50 non-null     float64
#  3   Primary language        50 non-null     object
#  4   Category                50 non-null     object
#  5   Country                 50 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 2.5+ KB
#        Subscribers (millions)
# count               50.000000
# mean                76.208000
# std                 39.735225
# min                 46.300000
# 25%                 53.800000
# 50%                 60.300000
# 75%                 83.950000
# max                249.000000

# %%
df.sort_values(by="Subscribers (millions)", ascending=False)
# Out:
#                                      Name Brand channel  \
# 0                                T-Series           Yes
# 1                                 MrBeast            No
# 2                               Cocomelon           Yes
# 3     Sony Entertainment Television India           Yes
# 4                         Kids Diana Show           Yes
# 5                               PewDiePie            No
# 6                             Like Nastya            No
# 7                           Vlad and Niki            No
# 8                       Zee Music Company           Yes
# 9                                     WWE           Yes
# 10                              Blackpink            No
# 11                              Goldmines           Yes
# 12                               Sony SAB           Yes
# 13                        5-Minute Crafts           Yes
# 14                              BangtanTV            No
# 15                            Hybe Labels           Yes
# ...

# %%
df["Subscribers (millions)"].mean()
# Out:
# 76.208

# %%
df[:1] #first line
# Out:
#        Name Brand channel  Subscribers (millions) Primary language Category  \
# 0  T-Series           Yes                   249.0      Hindi[7][8]    Music
#
#   Country
# 0   India

# %%
df[-1:] #last line
# Out:
#           Name Brand channel  Subscribers (millions) Primary language  \
# 49  Fernanfloo            No                    46.3          Spanish
#
#    Category      Country
# 49    Games  El Salvador

# %%
df['Category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %%
df['Country'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Country'>

# %%
#select all channels above 100 million subscribers:
df[df['Subscribers (millions)']>100]
# Out:
#                                   Name Brand channel  Subscribers (millions)  \
# 0                             T-Series           Yes                   249.0
# 1                              MrBeast            No                   184.0
# 2                            Cocomelon           Yes                   165.0
# 3  Sony Entertainment Television India           Yes                   162.0
# 4                      Kids Diana Show           Yes                   113.0
# 5                            PewDiePie            No                   111.0
# 6                          Like Nastya            No                   107.0
# 7                        Vlad and Niki            No                   101.0
#
#       Primary language       Category                 Country
# 0          Hindi[7][8]          Music                   India
# 1              English  Entertainment           United States
# 2              English      Education           United States
# ...
